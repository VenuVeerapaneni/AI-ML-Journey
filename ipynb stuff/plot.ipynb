# %%
import pandas as pd
df=pd.read_csv("Students.csv")

import matplotlib.pyplot as plt
plt.bar(df["Name"],df["Math"])
plt.show()

# %%
x = [1,2,3,4]
y = [10,20,15,25]

plt.plot(x, y)
plt.show()

# %%
marks = [70,80,90,85,95,60]

plt.hist(marks)
plt.show()

# %%
x = [1,2,3,4]
y = [2,4,5,8]

plt.scatter(x, y)
plt.show()
