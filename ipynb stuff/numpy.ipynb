# %%
import numpy as np

a=np.array([1,2,3])
print(a+5)
# Out:
# [6 7 8]

# %%
a=np.array([[10,20,30],[1,2,3]])
b=np.array([[1,2,3],[10,20,30]])

print(a @ b.T)
# Out:
# [[ 140 1400]
#  [  14  140]]

# %%
a=np.array([1,2,3,4,5])
a=a.reshape(5,1)
print(a)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]
