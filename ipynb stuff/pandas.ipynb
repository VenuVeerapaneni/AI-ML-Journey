# %%
import pandas as pd

data={
    "Name":["A","B","C"],
    "Age":[20,21,19],
    "Marks":[90,85,95]
}

df=pd.DataFrame(data)

print(df)
# Out:
#   Name  Age  Marks
# 0    A   20     90
# 1    B   21     85
# 2    C   19     95

# %%
df=pd.read_csv("students.csv")

print(df)
# Out:
#      Name  Math  Science  English  Hours_Studied
# 0   Aarav    85       78       90              4
# 1    Diya    92       88       95              6
# 2   Rahul    70       65       72              2
# 3   Sneha    88       91       84              5
# 4   Kiran    60       58       65              1
# 5  Ananya    95       94       96              7
# 6  Vikram    76       80       74              3
# 7   Meera    89       85       92              5
# 8   Arjun    55       60       58              1
# 9    Isha    91       89       93              6

# %%
print(df.head())
# Out:
#     Name  Math  Science  English  Hours_Studied
# 0  Aarav    85       78       90              4
# 1   Diya    92       88       95              6
# 2  Rahul    70       65       72              2
# 3  Sneha    88       91       84              5
# 4  Kiran    60       58       65              1

# %%
print(df.shape)
# Out:
# (10, 5)

# %%
print(df["Math"].mean())
# Out:
# 80.1

# %%
print(df["Science"].max())
# Out:
# 94

# %%
print(df[df["Hours_Studied"]>4])
# Out:
#      Name  Math  Science  English  Hours_Studied
# 1    Diya    92       88       95              6
# 3   Sneha    88       91       84              5
# 5  Ananya    95       94       96              7
# 7   Meera    89       85       92              5
# 9    Isha    91       89       93              6

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           10 non-null     str
#  1   Math           10 non-null     int64
#  2   Science        10 non-null     int64
#  3   English        10 non-null     int64
#  4   Hours_Studied  10 non-null     int64
# dtypes: int64(4), str(1)
# memory usage: 532.0 bytes

# %%
df.describe()
# Out:
#             Math    Science    English  Hours_Studied
# count  10.000000  10.000000  10.000000      10.000000
# mean   80.100000  78.800000  81.900000       4.000000
# std    14.145671  13.273198  13.674388       2.160247
# min    55.000000  58.000000  58.000000       1.000000
# 25%    71.500000  68.250000  72.500000       2.250000
# 50%    86.500000  82.500000  87.000000       4.500000
# 75%    90.500000  88.750000  92.750000       5.750000
# max    95.000000  94.000000  96.000000       7.000000
